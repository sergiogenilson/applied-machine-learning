# %% [markdown]
# # Using COCO
#
# First, we will import fiftyone lib and dowload the datasets.
#
# ## ALERT
#
# COCO is a very large dataset. Be sure that you have space in your disks to download it.

# %%
# from https://medium.com/voxel51/the-coco-dataset-best-practices-for-downloading-visualization-and-evaluation-68a3d7e97fb7
import fiftyone as fo
import fiftyone.zoo as foz

# Download person, cat and dog Validation dataset

# val2017 = foz.load_zoo_dataset(
#     "coco-2017",
#     split="validation",
#     label_types=["detections"],
#     classes=["person", "cat", "dog"],    
# )

# session = fo.launch_app(val2017)

train = foz.load_zoo_dataset(
    "coco-2017",
    split="train",
    label_types=["detections"],
    classes=["person", "cat", "dog"],
    max_samples=100 # remove limitations if project is working
)

test = foz.load_zoo_dataset(
    "coco-2017",
    split="test",
    label_types=["detections"],
    classes=["person", "cat", "dog"],
    max_samples=100 # remove limitations if project is working
)

validation = foz.load_zoo_dataset(
    "coco-2017",
    split="validation",
    label_types=["detections"],
    classes=["person", "cat", "dog"],
    max_samples=100 # remove limitations if project is working
)
# Out:
# Downloading split 'train' to '/home/sergio/fiftyone/coco-2017/train' if necessary
# Found annotations at '/home/sergio/fiftyone/coco-2017/raw/instances_train2017.json'
# Sufficient images already downloaded
# Existing download of split 'train' is sufficient
# Loading existing dataset 'coco-2017-train-100'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use
# Downloading split 'test' to '/home/sergio/fiftyone/coco-2017/test' if necessary
# Test split is unlabeled; ignoring classes requirement
# Found test info at '/home/sergio/fiftyone/coco-2017/raw/image_info_test2017.json'
# Sufficient images already downloaded
# Existing download of split 'test' is sufficient
# Loading existing dataset 'coco-2017-test-100'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use
# Downloading split 'validation' to '/home/sergio/fiftyone/coco-2017/validation' if necessary
# Found annotations at '/home/sergio/fiftyone/coco-2017/raw/instances_val2017.json'
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading existing dataset 'coco-2017-validation-100'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use

# %%
# Look at the data
session = fo.launch_app(validation)
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# #focontainer-4a2e28cf-c70c-4a14-bab3-d0d5686b941c {
#   position: relative;
#   display: block !important;
# }
# #foactivate-4a2e28cf-c70c-4a14-bab3-d0d5686b941c {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-4a2e28cf-c70c-4a14-bab3-d0d5686b941c:focus {
#   outline: none;
# }
# #fooverlay-4a2e28cf-c70c-4a14-bab3-d0d5686b941c {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-4a2e28cf-c70c-4a14-bab3-d0d5686b941c">
#    <div id="fooverlay-4a2e28cf-c70c-4a14-bab3-d0d5686b941c" style="display: none;">
#       <button id="foactivate-4a2e28cf-c70c-4a14-bab3-d0d5686b941c" >Activate</button>
#    </div>
#    <img src='data:image/png;base64,...' style="width: 100%; max-width: 2136px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-4a2e28cf-c70c-4a14-bab3-d0d5686b941c");
#      var overlay = document.getElementById("fooverlay-4a2e28cf-c70c-4a14-bab3-d0d5686b941c");
#      fetch(`http://localhost:5151/notebook?handleId=4a2e28cf-c70c-4a14-bab3-d0d5686b941c`)
#      .then((response) => response.json())
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/reactivate?handleId=4a2e28cf-c70c-4a14-bab3-d0d5686b941c`)
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %%
# filterirg detections

for item in train:
    item.ground_truth.detections = [detection for detection in item.ground_truth.detections if detection.label in ['cat', 'dog', 'person']]
    # print(item.filename, [detection.label for detection in item.ground_truth.detections])

for item in train:
    # item.ground_truth.detections = [detection for detection in item.ground_truth.detections if detection.label in ['cat', 'dog', 'person']]
    print(item.filename, [detection.label for detection in item.ground_truth.detections])


for item in validation:
    item.ground_truth.detections = [detection for detection in item.ground_truth.detections if detection.label in ['cat', 'dog', 'person']]
# Out:
# <Sample: {
#     'id': '62294a31084477e70eccb30e',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000001319.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 518,
#         'height': 600,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb306',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dog',
#                 'bounding_box': BaseList([
#                     0.6066795366795367,
#                     0.23199999999999998,
#                     0.1684169884169884,
#                     0.2617333333333333,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb308',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cat',
#                 'bounding_box': BaseList([
#                     0.5653861003861004,
#                     0.4659833333333333,
#                     0.3977799227799228,
#                     0.48596666666666666,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb309',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cat',
#                 'bounding_box': BaseList([
#                     0.047181467181467186,
#                     0.19575,
#                     0.6056370656370657,
#                     0.7741166666666667,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb30a',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.6259073359073359,
#                     0.16098333333333334,
#                     0.3740926640926641,
#                     0.3206333333333333,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb326',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000019304.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 500,
#         'height': 375,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb317',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dog',
#                 'bounding_box': BaseList([
#                     0.0679,
#                     0.35842666666666667,
#                     0.49498000000000003,
#                     0.5231466666666666,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb318',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cat',
#                 'bounding_box': BaseList([0.41792, 0.196, 0.3499, 0.39957333333333334]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb319',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([0.4264, 0.00224, 0.14158, 0.15282666666666667]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb327',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000025551.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 640,
#         'height': 426,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb31a',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dog',
#                 'bounding_box': BaseList([
#                     0.7258281249999999,
#                     0.42582159624413146,
#                     0.061406249999999996,
#                     0.15894366197183096,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb31e',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.374359375,
#                     0.5180985915492958,
#                     0.041765625,
#                     0.12460093896713614,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb31f',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.5081562500000001,
#                     0.5006338028169014,
#                     0.02375,
#                     0.051877934272300474,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb322',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cat',
#                 'bounding_box': BaseList([
#                     0.726359375,
#                     0.42413145539906105,
#                     0.072328125,
#                     0.16870892018779343,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb323',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.40384374999999995,
#                     0.5116666666666667,
#                     0.029734375,
#                     0.030892018779342723,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb324',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.7070624999999999,
#                     0.33579812206572773,
#                     0.083609375,
#                     0.4354225352112676,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb347',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000042169.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 395,
#         'height': 640,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb337',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dog',
#                 'bounding_box': BaseList([
#                     0.09129113924050633,
#                     0.6038125,
#                     0.3096962025316456,
#                     0.33601562500000004,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb338',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cat',
#                 'bounding_box': BaseList([
#                     0.394379746835443,
#                     0.374171875,
#                     0.1942784810126582,
#                     0.11078125000000001,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb339',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.30663291139240506,
#                     0.256453125,
#                     0.39721518987341775,
#                     0.705375,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb348',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000060539.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 500,
#         'height': 334,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb33b',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cat',
#                 'bounding_box': BaseList([
#                     0.19436,
#                     0.13038922155688623,
#                     0.36854000000000003,
#                     0.4482634730538922,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb33d',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.19101796407185628,
#                     1.0,
#                     0.7932634730538922,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb33f',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dog',
#                 'bounding_box': BaseList([
#                     0.5719,
#                     0.5078443113772455,
#                     0.18228,
#                     0.18961077844311378,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70ecc

#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.005059999999999999,
#                     0.7370818505338078,
#                     0.19448,
#                     0.26291814946619213,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb38d',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000182759.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 480,
#         'height': 640,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb381',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dog',
#                 'bounding_box': BaseList([0.0, 0.3066875, 1.0, 0.5263125]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb382',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cat',
#                 'bounding_box': BaseList([
#                     0.19902083333333334,
#                     0.177,
#                     0.46658333333333335,
#                     0.354,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb383',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.3265,
#                     0.0029375,
#                     0.36762500000000004,
#                     0.340203125,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb38e',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000191169.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 426,
#         'height': 640,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb384',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cat',
#                 'bounding_box': BaseList([
#                     0.16476525821596244,
#                     0.18925,
#                     0.4361737089201878,
#                     0.44085937499999994,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb385',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.3362910798122066,
#                     0.11278125000000001,
#                     0.5001643192488263,
#                     0.7258125,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb386',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dog',
#                 'bounding_box': BaseList([
#                     0.7531455399061032,
#                     0.619796875,
#                     0.2468544600938967,
#                     0.130515625,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb442',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000218114.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 640,
#         'height': 480,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb3bb',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dog',
#                 'bounding_box': BaseList([
#                     0.5070781249999999,
#                     0.33097916666666666,
#                     0.405375,
#                     0.28339583333333335,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb3bc',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cat',
#                 'bounding_box': BaseList([
#                     0.171109375,
#                     0.4475,
#                     0.45289062500000005,
#                     0.3190625,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb3bd',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.12334375,
#                     0.043854166666666666,
#                     0.6429843749999999,
#                     0.5305416666666667,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb443',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000224049.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 640,
#         'height': 426,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb3bf',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cat',
#                 'bounding_box': BaseList([
#                     0.576875,
#                     0.7795305164319248,
#                     0.11515625,
#                     0.14098591549295775,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb3c1',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.45317187499999995,
#                     0.2398591549295775,
#                     0.092671875,
#                     0.3553755868544601,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb3c4',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dog',
#                 'bounding_box': BaseList([
#                     0.56859375,
#                     0.7013615023474178,
#                     0.080296875,
#                     0.09598591549295775,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb444',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000248091.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 375,
#         'height': 500,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb3c6',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dog',
#                 'bounding_box': BaseList([
#                     0.15354666666666666,
#                     0.19938,
#                     0.3474666666666667,
#                     0.45656,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb3c8',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cat',
#                 'bounding_box': BaseList([
#                     0.6256266666666667,
#                     0.6989,
#                     0.17648000000000003,
#                     0.13516,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb3d0',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.003466666666666667,
#                     0.29610000000000003,
#                     0.10736,
#                     0.27532,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb445',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000257909.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 640,
#         'height': 480,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb3d4',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dog',
#                 'bounding_box': BaseList([
#                     0.583484375,
#                     0.7175208333333334,
#                     0.0518125,
#                     0.05391666666666666,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb3d6',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.48315625000000006,
#                     0.5277708333333334,
#                     0.05254687500000001,
#                     0.24291666666666664,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb3d7',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cat',
#                 'bounding_box': BaseList([
#                     0.5839531250000001,
# ...
#             <Detection: {
#                 'id': '62294a31084477e70eccb80a',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.329734375,
#                     0.36332552693208425,
#                     0.025328125,
#                     0.10533957845433255,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb83b',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000000474.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 333,
#         'height': 500,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb80b',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.01012012012012012,
#                     0.0854,
#                     0.9886186186186185,
#                     0.85842,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb83c',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000000488.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 640,
#         'height': 406,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb80e',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.2824375,
#                     0.5179802955665025,
#                     0.163484375,
#                     0.32273399014778326,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb80f',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.175375,
#                     0.6042364532019704,
#                     0.1984375,
#                     0.27280788177339904,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb813',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.32703125,
#                     0.48741379310344823,
#                     0.039703125,
#                     0.17426108374384236,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb814',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.8536250000000001,
#                     0.5331280788177339,
#                     0.068953125,
#                     0.12133004926108373,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb815',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.054171875,
#                     0.5123645320197044,
#                     0.14256249999999998,
#                     0.3752709359605912,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62294a31084477e70eccb816',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.3505625,
#                     0.44793103448275867,
#                     0.00690625,
#                     0.019729064039408866,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# <Sample: {
#     'id': '62294a31084477e70eccb83d',
#     'media_type': 'image',
#     'filepath': '/home/sergio/fiftyone/coco-2017/train/data/000000000490.jpg',
#     'tags': BaseList(['train']),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 500,
#         'height': 495,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62294a31084477e70eccb817',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dog',
#                 'bounding_box': BaseList([
#                     0.092,
#                     0.3898989898989899,
#                     0.18,
#                     0.28888888888888886,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'animal',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>
# 000000001319.jpg ['dog', 'tv', 'cat', 'cat', 'person', 'tie', 'cup', 'book']
# 000000019304.jpg ['dog', 'cat', 'person']
# 000000025551.jpg ['dog', 'car', 'car', 'car', 'person', 'person', 'truck', 'truck', 'cat', 'person', 'person', 'truck']
# 000000042169.jpg ['dog', 'cat', 'person', 'umbrella']
# 000000060539.jpg ['cat', 'couch', 'person', 'laptop', 'dog', 'bed']
# 000000067004.jpg ['dog', 'cat', 'person']
# 000000124122.jpg ['dog', 'person', 'cat']
# 000000130047.jpg ['dog', 'cat', 'person']
# 000000153559.jpg ['dog', 'cat', 'cat', 'cat', 'cat', 'person', 'backpack']
# 000000172597.jpg ['dog', 'cat', 'person', 'bed', 'remote', 'chair']
# 000000174871.jpg ['dog', 'cat', 'motorcycle', 'person', 'person', 'person', 'person', 'motorcycle', 'person', 'person', 'person']
# 000000175491.jpg ['cat', 'couch', 'person', 'handbag', 'dog']
# 000000175820.jpg ['dog', 'cat', 'person', 'remote', 'potted plant', 'remote']
# 000000182759.jpg ['dog', 'cat', 'person']
# 000000191169.jpg ['cat', 'person', 'dog']
# 000000218114.jpg ['dog', 'cat', 'person', 'bed']
# 000000224049.jpg ['cat', 'couch', 'person', 'cup', 'couch', 'dog', 'couch']
# 000000248091.jpg ['dog', 'tv', 'cat', 'tv', 'laptop', 'chair', 'mouse', 'book', 'vase', 'tv', 'person', 'laptop', 'keyboard', 'book']
# 000000257909.jpg ['dog', 'bird', 'person', 'cat']
# 000000264514.jpg ['dog', 'cat', 'bowl', 'handbag', 'person', 'suitcase']
# 000000273885.jpg ['dog', 'cat', 'person']
# 000000291257.jpg ['dog', 'cat', 'person', 'bed']
# 000000300415.jpg ['dog', 'dog', 'cat', 'bottle', 'bottle', 'bottle', 'bottle', 'person', 'potted plant', 'refrigerator', 'cup', 'knife', 'knife', 'knife', 'oven', 'sink', 'bottle', 'bottle', 'knife', 'potted plant', 'dog', 'cup', 'cup', 'potted plant', 'potted plant', 'potted plant', 'potted plant', 'potted plant', 'potted plant', 'potted plant', 'potted plant']
# 000000307423.jpg ['dog', 'cat', 'car', 'person']
 'person', 'person', 'person', 'person', 'person', 'person', 'person', 'person', 'person', 'backpack', 'person', 'person', 'person']
# 000000000394.jpg ['dog', 'frisbee']
# 000000000395.jpg ['cell phone', 'person', 'person', 'person', 'person', 'cell phone', 'person', 'person', 'person', 'person', 'person', 'person', 'person']
# 000000000397.jpg ['chair', 'pizza', 'cup', 'cup', 'fork', 'dining table', 'person']
# 000000000400.jpg ['dog', 'boat']
# 000000000415.jpg ['tennis racket', 'person']
# 000000000419.jpg ['person', 'tennis racket', 'sports ball', 'person', 'car', 'car', 'car']
# 000000000428.jpg ['tie', 'person', 'cake']
# 000000000431.jpg ['sports ball', 'person', 'tennis racket']
# 000000000436.jpg ['person', 'donut']
# 000000000443.jpg ['cat', 'person', 'person', 'remote', 'couch', 'person']
# 000000000446.jpg ['person', 'remote', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'couch', 'potted plant', 'potted plant', 'potted plant']
# 000000000459.jpg ['tie', 'person']
# 000000000471.jpg ['bus', 'person']
# 000000000474.jpg ['person', 'baseball glove']
# 000000000488.jpg ['sports ball', 'person', 'person', 'baseball bat', 'baseball glove', 'baseball glove', 'person', 'person', 'person', 'person']
# 000000000490.jpg ['dog', 'skateboard']

# %%
session = fo.launch_app(train)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=true&handleId=bb8c90f1-7b79-40ac-9b09-325682872cb4"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Export datasets to YOLO format
train_dir = "../datasets/COCOPP/train"
test_dir = "../datasets/COCOPP/test"
validation_dir = "../datasets/COCOPP/validation"

train.export(
    export_dir= train_dir,
    dataset_type=fo.types.YOLOv5Dataset
)
test.export(
    export_dir= test_dir,
    dataset_type=fo.types.YOLOv5Dataset,
)
validation.export(
    export_dir= validation_dir,
    dataset_type=fo.types.YOLOv5Dataset
)
# Out:
#  100% |█████████████████| 100/100 [336.1ms elapsed, 0s remaining, 297.5 samples/s]
#  100% |█████████████████| 100/100 [59.3ms elapsed, 0s remaining, 1.7K samples/s]
#  100% |█████████████████| 100/100 [303.4ms elapsed, 0s remaining, 329.6 samples/s]

# %%
# Remove classes that are not "cat", "dog" or "person"
import glob

def convert_classes(dir):
    for file in glob.glob(dir + "/labels/val/*.txt"):
        new_labels = ""
        with open(file) as f:
            for line in f:
                s = line.split(" ", 1)
                if s[0] == "1":  # person
                    new_labels += "0 " + s[1]
                elif s[0] == "17": # cat
                    new_labels += "1 " + s[1]
                elif s[0] == "18": # dog
                    new_labels += "2 " + s[1]
            f.close()
        
        fout = open(file, "w")
        fout.write(new_labels)
        fout.close()

convert_classes(validation_dir)
convert_classes(train_dir)

# %%
# Manage structure
import shutil
import os

shutil.move("../datasets/COCOPP/validation/images/val", "../datasets/COCOPP/images/valid")
shutil.move("../datasets/COCOPP/validation/labels/val", "../datasets/COCOPP/labels/valid")

shutil.move("../datasets/COCOPP/train/images/val", "../datasets/COCOPP/images/train")
shutil.move("../datasets/COCOPP/train/labels/val", "../datasets/COCOPP/labels/train")
# Out:
# '../datasets/COCOPP/labels/train'

# %%
# Remove old folders
shutil.rmtree("../datasets/COCOPP/validation")
shutil.rmtree("../datasets/COCOPP/train")
